# %%
# %pylab inline
import pandas as pd
import prettyplotlib as ppl
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

numberlist = open('number_list.csv').read()
numberlist = (int(n) for n in (numberlist.split('\r\n')[0]).split(','))

df = pd.DataFrame(numberlist, columns = ['numbers'])
df
# Out:
# Populating the interactive namespace from numpy and matplotlib
#     numbers
# 0        64
# 1        28
# 2        17
# 3        15
# 4        10
# 5         2
# 6        17
# 7        20
# 8        12
# 9        17
# 10       32
# 11       23
# 12       19
# 13       13
# 14       13
# 15       12
# 16       22
# 17       10
# 18       26
# 19       13
# 20       29
# 21       26
# 22       24
# 23       23
# 24       15
# 25       19
# 26        6
# 27       21
# 28       24
# 29       25
# 30       22
# 31       24
# 32       25
# 33       22
# 34       15
# 35       10
# 36       11
# 37       45
# 38       35
# 39       22
# 40       13
# 41       12
# 42       28
# 43       10
# 44       19
# 45       27
# 46       17
# 47       23
# 48       29
# 49       13
# 50       42
# 51       27
# 52       16
# 53       24
# 54       24
# 55       17
# 56       52
# 57       28
# 58       14
# 59       16
#         ...
#
# [1031 rows x 1 columns]

# %%
bn_less = df[(df['numbers']<50) & (df['numbers']>4)]
bn_less.describe()
# Out:
#           numbers
# count  958.000000
# mean    20.277662
# std      8.289444
# min      5.000000
# 25%     14.000000
# 50%     19.000000
# 75%     25.000000
# max     49.000000
#
# [8 rows x 1 columns]

# %%
font = {'size'   : 12}

plt.rc('font', **font)

plt.figure()

# bn_less.hist(bins = len(bn_less))
# plt.xlabel('Mean score by postcode', fontsize=20)
# plt.ylabel('Count', fontsize= 18)
# plt.show()

his = np.histogram(bn_less,bins=range(bn_less.min(),bn_less.max()+2))
fig, ax = plt.subplots()
offset = .5
width = 0.5
ind = (np.arange(bn_less.min(),bn_less.max()+1))
ax.bar(ind - offset,his[0],width)
ax.set_xticks(ind)
# xts = range(bn_less.max())
xts = [str(x) if x%5==0 else '' for x in ind] 
ax.set_xticklabels(tuple(xts))
plt.xlim((5,50))
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-31-d8156f864354> in <module>()
#      15 width = 0.5
#      16 ind = (np.arange(bn_less.min(),bn_less.max()+1))
# ---> 17 ax.bar(ind - offset,his[0],width)
#      18 ax.set_xticks(ind)
#      19 # xts = range(bn_less.max())
#
# /Users/dino/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    4997         assert len(height) == nbars, ("incompatible sizes: argument 'height' "
#    4998                                       "must be length %d or scalar" %
# -> 4999                                       nbars)
#    5000         assert len(width) == nbars, ("incompatible sizes: argument 'width' "
#    5001                                      "must be length %d or scalar" %
#
# AssertionError: incompatible sizes: argument 'height' must be length 45 or scalar
